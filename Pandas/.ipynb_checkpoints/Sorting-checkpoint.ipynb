# %%
import pandas as pd

# %%
unsorted_imdb_rating = pd.read_csv('unsorted_imdb_rating.csv')

# %%
unsorted_imdb_rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.1                                  The Godfather      Crime
# 2          9.2                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.8                                   12 Angry Men      Drama
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
unsorted_imdb_rating.index = [8,9,1,3,2,4,5,7,6,0]

# %%
unsorted_imdb_rating
# Out:
#    star_rating                                          title      genre  \
# 8          9.3                       The Shawshank Redemption      Crime
# 9          9.1                                  The Godfather      Crime
# 1          9.2                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 2          8.9                                   Pulp Fiction      Crime
# 4          8.8                                   12 Angry Men      Drama
# 5          8.7                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 6          8.3                               Schindler's List  Biography
# 0          8.1                                     Fight Club      Drama
#
#    duration
# 8       142
# 9       175
# 1       200
# 3       152
# 2       154
# 4        96
# 5       161
# 7       201
# 6       195
# 0       139

# %%
unsorted_imdb_rating.sort_index()
# Out:
#    star_rating                                          title      genre  \
# 0          8.1                                     Fight Club      Drama
# 1          9.2                         The Godfather: Part II      Crime
# 2          8.9                                   Pulp Fiction      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.8                                   12 Angry Men      Drama
# 5          8.7                 The Good, the Bad and the Ugly    Western
# 6          8.3                               Schindler's List  Biography
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          9.3                       The Shawshank Redemption      Crime
# 9          9.1                                  The Godfather      Crime
#
#    duration
# 0       139
# 1       200
# 2       154
# 3       152
# 4        96
# 5       161
# 6       195
# 7       201
# 8       142
# 9       175

# %%
unsorted_imdb_rating.sort_index(ascending=False)
# Out:
#    star_rating                                          title      genre  \
# 9          9.1                                  The Godfather      Crime
# 8          9.3                       The Shawshank Redemption      Crime
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 6          8.3                               Schindler's List  Biography
# 5          8.7                 The Good, the Bad and the Ugly    Western
# 4          8.8                                   12 Angry Men      Drama
# 3          9.0                                The Dark Knight     Action
# 2          8.9                                   Pulp Fiction      Crime
# 1          9.2                         The Godfather: Part II      Crime
# 0          8.1                                     Fight Club      Drama
#
#    duration
# 9       175
# 8       142
# 7       201
# 6       195
# 5       161
# 4        96
# 3       152
# 2       154
# 1       200
# 0       139

# %%
unsorted_imdb_rating.sort_index(axis=1)
# Out:
#    duration      genre  star_rating  \
# 8       142      Crime          9.3
# 9       175      Crime          9.1
# 1       200      Crime          9.2
# 3       152     Action          9.0
# 2       154      Crime          8.9
# 4        96      Drama          8.8
# 5       161    Western          8.7
# 7       201  Adventure          8.9
# 6       195  Biography          8.3
# 0       139      Drama          8.1
#
#                                            title
# 8                       The Shawshank Redemption
# 9                                  The Godfather
# 1                         The Godfather: Part II
# 3                                The Dark Knight
# 2                                   Pulp Fiction
# 4                                   12 Angry Men
# 5                 The Good, the Bad and the Ugly
# 7  The Lord of the Rings: The Return of the King
# 6                               Schindler's List
# 0                                     Fight Club

# %%
unsorted_imdb_rating['star_rating'].sort_index()
# Out:
# 0    8.1
# 1    9.2
# 2    8.9
# 3    9.0
# 4    8.8
# 5    8.7
# 6    8.3
# 7    8.9
# 8    9.3
# 9    9.1
# Name: star_rating, dtype: float64

# %%
unsorted_imdb_rating['genre'].sort_index()
# Out:
# 0        Drama
# 1        Crime
# 2        Crime
# 3       Action
# 4        Drama
# 5      Western
# 6    Biography
# 7    Adventure
# 8        Crime
# 9        Crime
# Name: genre, dtype: object

# %%
unsorted_imdb_rating.sort_values(by='duration')
# Out:
#    star_rating                                          title      genre  \
# 4          8.8                                   12 Angry Men      Drama
# 0          8.1                                     Fight Club      Drama
# 8          9.3                       The Shawshank Redemption      Crime
# 3          9.0                                The Dark Knight     Action
# 2          8.9                                   Pulp Fiction      Crime
# 5          8.7                 The Good, the Bad and the Ugly    Western
# 9          9.1                                  The Godfather      Crime
# 6          8.3                               Schindler's List  Biography
# 1          9.2                         The Godfather: Part II      Crime
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
#
#    duration
# 4        96
# 0       139
# 8       142
# 3       152
# 2       154
# 5       161
# 9       175
# 6       195
# 1       200
# 7       201

# %%
unsorted_imdb_rating.sort_values(by='genre')
# Out:
#    star_rating                                          title      genre  \
# 3          9.0                                The Dark Knight     Action
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 6          8.3                               Schindler's List  Biography
# 8          9.3                       The Shawshank Redemption      Crime
# 9          9.1                                  The Godfather      Crime
# 1          9.2                         The Godfather: Part II      Crime
# 2          8.9                                   Pulp Fiction      Crime
# 4          8.8                                   12 Angry Men      Drama
# 0          8.1                                     Fight Club      Drama
# 5          8.7                 The Good, the Bad and the Ugly    Western
#
#    duration
# 3       152
# 7       201
# 6       195
# 8       142
# 9       175
# 1       200
# 2       154
# 4        96
# 0       139
# 5       161

# %%
unsorted_imdb_rating[['star_rating','title','genre']].sort_values(by=['genre','star_rating'])
# Out:
#    star_rating                                          title      genre
# 3          9.0                                The Dark Knight     Action
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 6          8.3                               Schindler's List  Biography
# 2          8.9                                   Pulp Fiction      Crime
# 9          9.1                                  The Godfather      Crime
# 1          9.2                         The Godfather: Part II      Crime
# 8          9.3                       The Shawshank Redemption      Crime
# 0          8.1                                     Fight Club      Drama
# 4          8.8                                   12 Angry Men      Drama
# 5          8.7                 The Good, the Bad and the Ugly    Western
