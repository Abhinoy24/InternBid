# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv("Document.csv")

# %%
data
# Out:
#                                    Category  No of documents
# 0                       Aerial Construction              0.0
# 1                             Bridge Repair              8.0
# 2                               Bridge Work              6.0
# 3                Building - Non-Residential              2.0
# 4                    Building - Residential             10.0
# 5                        Concrete & Masonry             64.0
# 6                Cured-In-Place-Pipe (CIPP)             19.0
# 7                        Directional Boring              1.0
# 8                           Electrical Work             31.0
# 9                             Environmental              7.0
# 10                     Excavation & Grading             58.0
# 11                                     HVAC             17.0
# 12                            Jack and Bore              1.0
# 13                            Manhole Rehab             12.0
# ...

# %%
nrows = len(data.iloc[:,0])

# %%
nrows
# Out:
# 499

# %%
unlabel = []

# %%
for i in range(nrows):
    for j in range(2):
        if data.iloc[i][j] == 0.0:
            unlabel.append(data.iloc[i][0])
        else:
            continue

# %%
len(unlabel)
# Out:
# 193

# %%
unlabel
# Out:
# ['Aerial Construction',
#  'Microtunneling',
#  'Pipe Bursting',
#  'Pipe Lining',
#  'Pipe Ramming',
#  'Slip-Lining',
#  'Trenching & Plowing',
#  'Tunneling',
#  'Pipeline',
#  'Gas Transmission',
#  'Water Well Drilling & Maint',
#  'Boring/ Vertical',
#  'Water Distribution',
#  'Water Transmission',
#  'Fold & Form',
#  'Clearing & Grubbing',
#  'Landfill Work',
#  'Dredging',
#  'Pump/Lift Station-water/sewer',
#  'Cable TV',
#  'Broadband Internet',
#  'Instrumentation',
#  'Dewatering',
#  'Misc. Construction',
#  'Gas Distribution',
#  'Root Control',
#  'Generator/ Installation & Maintenance',
#  'Pipe & Manhole Grouting',
#  'Zoo/ Aquarium & Museum Const. & Maint.',
#  'Water Hydrant',
#  'Sludge & Bio-Solids Disposal',
#  'Shotcrete / Gunite',
#  'Mining & Mine Reclamation',
#  'Agriculture/ Food & Farming',
#  'Mining/ Mineral/ Oil & Gas Extraction',
#  'Manufacturing',
#  'Wholesale Goods',
#  'Retail Goods',
#  'Accomodation & Lodging',
#  'Public Administration',
# ...
